# %%
from zai import ZaiClient, ZhipuAiClient

client = ZaiClient(api_key="73e51e1f99074ebda240f1950f31966e.t2yjVLHxMeuVFgRl")

# %%
# Create chat completion
response = client.chat.completions.create(
    model="glm-4.7",
    messages=[
        {"role": "user", "content": "Hello, Z.ai!"}
    ]
)
print(response.choices[0].message.content)

# %%
from core.state_mapping import main

# %%
main()
# Out:
# ======================================================================
# STATE-TO-STATE MAPPING via ENTANGLEMENT (Demo)
# ======================================================================
#
# Note: This is a simplified demo showing the workflow.
# Full implementation requires HRT evolution system.
# ✓ Extension registered: storage v1.4.4
# ✓ Extension registered: storage v1.4.4
#
# 1. Setting up perceptrons...
#
# 2. Processing MOS(t-1)...
#    State created: ...
#
# ======================================================================
# Demo complete - see demo_unified_storage.ipynb for working examples
# ======================================================================
